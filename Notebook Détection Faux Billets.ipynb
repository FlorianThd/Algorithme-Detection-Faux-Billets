# %% [markdown]
# **Création d'un algorithme de détection de faux billets** 💸
#
#
# 👨‍🎓 Projet de fin d'études réalisé en juin 2023 dans le cadre de la formation diplômante "Data Analyst" d'OpenClassRooms.
# 🛠 Mots clés : *Machine Learning, prédictions, K-means, régression logistique, régression linéaire.*
#
# ---
# <br>
# Le projet en quelques mots :<br>
# <br>
# Notre mission était ici de concevoir un algorithme de détection de faux billets pour une institution publique fictive garante de l'intégrité de la monnaie en circulation.
# À partir de six caractéristiques d'un billet de banque (hauteur, largeur, longueur de la diagonale, etc), l'algorithme devait pouvoir déterminer si celui-ci était vrai ou faux.
#
# Pour pouvoir construire et entraîner notre algorithme, nous avions à notre disposition les caractéristiques de 1500 billets, 500 faux et 1000 vrais.
#
# La stratégie mise en place a été de comparer deux méthodes de prédictions, pour ensuite choisir celle qui donnerait les meilleurs résultats (c'est à dire celle qui donnerait le moins de faux positifs et de faux négatifs).
#
# Les méthodes utilisées sont les suivantes :
#
# - Un algorithme de classification non-supervisée : la méthode K-means
# - Un algorithme de classification supervisée : une régression logistique
#
# Après avoir testé nos modèles sur notre échantillon de 1500 billets, nous constations que la méthode K-means permettait une prédiction correcte (un billet prédit comme étant vrai est-il réellement vrai ? Un billet prédit faux réellement faux ?) dans 98.53 % des cas, tandis que la régression logistique permettait une prédiction correcte dans 99.2 %, et fut donc retenu pour notre client.
#
#
# ---
# <br>
# 👋 Merci de votre lecture !  <br>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Exploration-des-données" data-toc-modified-id="Exploration-des-données-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><font color="#8333ff">Exploration des données</font></a></span><ul class="toc-item"><li><span><a href="#Représentations-visuelles-des-données" data-toc-modified-id="Représentations-visuelles-des-données-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Représentations visuelles des données</a></span></li><li><span><a href="#Création-d'un-dataframe-sans-valeur-manquante" data-toc-modified-id="Création-d'un-dataframe-sans-valeur-manquante-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Création d'un dataframe sans valeur manquante</a></span></li><li><span><a href="#Récapitulatif-des-DataFrames-utilisés" data-toc-modified-id="Récapitulatif-des-DataFrames-utilisés-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Récapitulatif des DataFrames utilisés</a></span></li></ul></li><li><span><a href="#Régression-linéaire-multiple" data-toc-modified-id="Régression-linéaire-multiple-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><font color="#8333ff">Régression linéaire multiple</font></a></span><ul class="toc-item"><li><span><a href="#Création-du-modèle" data-toc-modified-id="Création-du-modèle-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Création du modèle</a></span></li><li><span><a href="#Le-R²-ou-coefficient-de-détermination" data-toc-modified-id="Le-R²-ou-coefficient-de-détermination-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Le R² ou coefficient de détermination</a></span></li><li><span><a href="#Test-de-la-significativité-de-chaque-variable" data-toc-modified-id="Test-de-la-significativité-de-chaque-variable-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Test de la significativité de chaque variable</a></span></li><li><span><a href="#Test-de-la-normalité-des-résidus" data-toc-modified-id="Test-de-la-normalité-des-résidus-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Test de la normalité des résidus</a></span></li><li><span><a href="#Test-de-l'homo-scédasticité" data-toc-modified-id="Test-de-l'homo-scédasticité-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Test de l'homo-scédasticité</a></span></li><li><span><a href="#Variance-Inflation-Factor-(Multicolinéarité)" data-toc-modified-id="Variance-Inflation-Factor-(Multicolinéarité)-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Variance Inflation Factor (Multicolinéarité)</a></span></li><li><span><a href="#DataFrame-complété-des-données-prédites" data-toc-modified-id="DataFrame-complété-des-données-prédites-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>DataFrame complété des données prédites</a></span></li></ul></li><li><span><a href="#K-Means" data-toc-modified-id="K-Means-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><font color="#8333ff">K-Means</font></a></span><ul class="toc-item"><li><span><a href="#Détermination-du-nombre-de-clusters" data-toc-modified-id="Détermination-du-nombre-de-clusters-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Détermination du nombre de clusters</a></span></li><li><span><a href="#Création-du-modèle" data-toc-modified-id="Création-du-modèle-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Création du modèle</a></span></li><li><span><a href="#Prédiction-sur-les-données-test" data-toc-modified-id="Prédiction-sur-les-données-test-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Prédiction sur les données test</a></span></li></ul></li><li><span><a href="#Régression-logistique" data-toc-modified-id="Régression-logistique-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><font color="#8333ff">Régression logistique</font></a></span><ul class="toc-item"><li><span><a href="#Partage-des-données" data-toc-modified-id="Partage-des-données-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Partage des données</a></span></li><li><span><a href="#Création-du-modèle" data-toc-modified-id="Création-du-modèle-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Création du modèle</a></span></li><li><span><a href="#Evaluation-de-la-fiabilité-des-résultats" data-toc-modified-id="Evaluation-de-la-fiabilité-des-résultats-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Evaluation de la fiabilité des résultats</a></span></li><li><span><a href="#Prédiction-sur-les-données-test" data-toc-modified-id="Prédiction-sur-les-données-test-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Prédiction sur les données test</a></span></li></ul></li><li><span><a href="#Comparaison-des-deux-modèles" data-toc-modified-id="Comparaison-des-deux-modèles-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><font color="#8333ff">Comparaison des deux modèles<font></font></font></a></span><ul class="toc-item"><li><span><a href="#K-Means" data-toc-modified-id="K-Means-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>K-Means</a></span></li><li><span><a href="#Régression-logistique" data-toc-modified-id="Régression-logistique-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Régression logistique</a></span></li><li><span><a href="#Test-sur-les-nouvelles-données" data-toc-modified-id="Test-sur-les-nouvelles-données-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Test sur les nouvelles données</a></span></li></ul></li></ul></div>

# %% [markdown]
# <font color="#8333ff">**Import des librairies**</font>

# %%
# générales
import numpy as np
import pandas as pd

# %%
# pour la régression linéaire :
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# pour les évaluations des variables dans le cadre de la régression linéaire
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.diagnostic as smd
import pingouin as pg
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import t, shapiro

# %%
# pour K-Means
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from kneed import KneeLocator

# %%
# pour la PCA
from sklearn import preprocessing
from sklearn import decomposition

# %%
# pour la régression logistique
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %%
# graphiques
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from seaborn import pairplot, heatmap

# %% [markdown]
# <font color="#8333ff">**Import des données**</font>

# %%
bil = pd.read_csv("billets.csv",sep=";")

# %% [markdown]
# # <font color="#8333ff">Exploration des données</font>

# %%
bil.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %%
# on constate qu'il y a 37 valeurs manquantes pour la variable "margin_low"
bil.isna().sum()
# Out:
# is_genuine       0
# diagonal         0
# height_left      0
# height_right     0
# margin_low      37
# margin_up        0
# length           0
# dtype: int64

# %%
# plus en détail avec une méthode groupby :
bil.groupby("is_genuine").count()
# Out:
#             diagonal  height_left  height_right  margin_low  margin_up  length
# is_genuine
# False            500          500           500         492        500     500
# True            1000         1000          1000         971       1000    1000

# %% [markdown]
# On a 500 faux billets et 1000 vrais billets.
# Il y a 8 marges basses manquantes pour les faux et 29 pour les vrais.

# %%
# soit en pourcentage des données totales :
round(((bil["margin_low"].isna().sum() / 1500)*100),2)
# Out:
# 2.47

# %% [markdown]
# **Observons quelques caractéristiques de nos deux groupes "Vrai" et "Faux" :**

# %%
# les moyennes de chaque groupe
bil.groupby("is_genuine").mean()
# Out:
#              diagonal  height_left  height_right  margin_low  margin_up  \
# is_genuine
# False       171.90116    104.19034     104.14362    5.215935    3.35016
# True        171.98708    103.94913     103.80865    4.116097    3.05213
#
#                length
# is_genuine
# False       111.63064
# True        113.20243

# %% [markdown]
# ## Représentations visuelles des données

# %% [markdown]
# Regardons maintenant comment sont réparties nos données en fonction de leur appartenance au groupe 'vrai' ou 'faux'.

# %% [markdown]
# **Ce qu'on peut retenir des diagrammes ci-dessous c'est que certaines variables sont plus à même de nous renseigner sur la véracité des billets que d'autres.**
#
# Ainsi :
#
# --> La diagonale et la hauteur gauche ne distinguent pas vraiment les billets faux des vrais.<br>
# --> La longueur et la marge basse sont en revanche des bons marqueurs de la véracité d'un billet.<br>

# %%
sns.pairplot(bil,hue="is_genuine")
plt.show()

# %% [markdown]
# Autre façon de comparer visuellement les variables, via des "boxplots" :

# %%
sns.set(rc = {'figure.figsize':(15,8)})
fig = plt.figure()
def boxplots(var,i):
    ax = fig.add_subplot(i)
    ax = sns.boxplot(x= 'is_genuine', y = var, data = bil)
    plt.xlabel("Type de billet")
    plt.ylabel("Variable")
    plt.title("Dispersion de la variable "+str(var))
    
liste_variables = ["length","diagonal","height_left","height_right","margin_low","margin_up"]

i=321
for var in liste_variables :
    boxplots(var,i)
    i+=1
    
plt.subplots_adjust(top=2)
plt.show()

# %% [markdown]
# ## Création d'un dataframe sans valeur manquante

# %%
# Création d'un DataFrame sans valeurs manquantes
bil_nonan = bil[~bil.isnull().any(axis=1)]

# et on obtient alors un DataFrame de la forme suivante (#nb ligne #nb colonne):
bil_nonan.shape
# Out:
# (1463, 7)

# %%
# un aperçu de ce à quoi ressemble notre dataframe :
bil_nonan.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %% [markdown]
# ## Récapitulatif des DataFrames utilisés

# %% [markdown]
# <br>--> **bil** comprenant l'ensemble des billets (1500 lignes) <br>--> **bil_nan** comprenant uniquement les billets avec des données manquantes (37 lignes)<br>--> **bil_nonan** comprenant uniquement les billets aux données complètes (1463 lignes)<br>--> **bil2** qui sera notre Dataframe total complété avec les données prédites (1500 lignes)<br>--> **bil_false** et **bil_true** correspondants respectivement aux billets faux complets et aux billets vrais (sans données manquantes)

# %%
bil_false = bil_nonan[bil_nonan["is_genuine"]==False]
bil_true = bil_nonan[bil_nonan["is_genuine"]==True]

# %% [markdown]
# # <font color="#8333ff">Régression linéaire multiple</font>

# %% [markdown]
# ## Création du modèle

# %% [markdown]
# Afin de combler nos données manquantes, nous allons tenter d'estimer les données manquantes 'margin_low' **à partir des données des 5 autres variables quantitatives**.</br> <br> On appellera :<br> <br> --> **x_var** le DataFrame comprenant les 5 variables quantitatives que l'on connaît, <br> et <br> --> **y_var** la variable "margin_low" pour laquelle on cherche à recréer les données manquantes.

# %%
# nos variables quantitatives que l'on connaît
var_connues = ["diagonal","height_left","height_right","margin_up","length"]

# nos deux dataframes **variables connues** / **variable à prédire**
x_var = bil_nonan[var_connues]
y_var = bil_nonan["margin_low"]

# on crée une variable "lr" à partir d'un modèle linéaire "LinearRegression"
lr = LinearRegression()

# on entraîne notre variable lr avec les données x_var, y_var
lr.fit(x_var,y_var)

# sur la base de cet entraînement on génére une prédiction y_predict 
y_predict = lr.predict(x_var)

# %% [markdown]
# ## Le R² ou coefficient de détermination

# %% [markdown]
# Notre modèle de prédiction est naturellement imparfait.
#
# Le coefficient de détermination, appelé R², représente la part de la variation de la variable Y (dans notre cas, margin_low) expliquée par notre modèle.
#
# Il est le rapport entre la SCE
# (Somme des Carrés Expliquée => traduit la part de la variation expliquée par le modèle.)
# et la SCT (Somme des Carrés Totale=> traduit la variation totale de Y).
#
# Plus le R² est élevé, plus le modèle explique une large part de la variation de Y.
#
#
# Voyons maintenant si notre modèle réalise des prédictions fiables, grâce au coéfficient de détermination :

# %%
lr.score(x_var, y_var)
# Out:
# 0.4773366973063957

# %% [markdown]
# **Le R² est malheureusement très bas. Le modèle explique une faible part de la variation de notre varibale dépendante.<br> Nous allons tenter de trouver les variables qui contribuent le moins et le plus à la prédiction de notre variable dépendante.**

# %%
var_qti = bil_nonan.columns.drop('is_genuine').tolist() # création de la liste de toutes les variables quantitatives
display(var_qti)
display(var_connues) # en comparaison, var_connues donne les variables quanti hormis 'margin_low'
# Out:
# ['diagonal',
#  'height_left',
#  'height_right',
#  'margin_low',
#  'margin_up',
#  'length']
# ['diagonal', 'height_left', 'height_right', 'margin_up', 'length']

# %% [markdown]
# ## Test de la significativité de chaque variable

# %%
reg_multi = log_reg = smf.ols('margin_low~diagonal+height_left+height_right+margin_up+length', data=bil_nonan).fit()
print(reg_multi.summary())

# Tous les paramètres sont significatifs.( P>|t| quasi égal à 0)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.477
# Model:                            OLS   Adj. R-squared:                  0.476
# Method:                 Least Squares   F-statistic:                     266.1
# Date:                Fri, 23 Jun 2023   Prob (F-statistic):          2.60e-202
# Time:                        07:24:42   Log-Likelihood:                -1001.3
# No. Observations:                1463   AIC:                             2015.
# Df Residuals:                    1457   BIC:                             2046.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       22.9948      9.656      2.382      0.017       4.055      41.935
# ...

# %% [markdown]
# ## Test de la normalité des résidus

# %% [markdown]
# Notre modèle étant imparfait,
# essayons de représenter la "part d'erreur" de cette prédiction,<br>
# c'est à dire notre prédiction moins les données réelles, observées.

# %%
display(y_var.values) # nos données réelles
display(np.round(y_predict,2)) # nos données prédites
residus = y_var - y_predict # calculs de la différence "données réelles" - "données prédites"
display(residus.values)
plt.hist(residus)
plt.show()
# Out:
# array([4.52, 3.77, 4.4 , ..., 5.51, 5.17, 4.63])
# array([4.79, 4.14, 4.13, ..., 4.9 , 4.81, 4.84])
# array([-0.26867649, -0.36890773,  0.27406738, ...,  0.60972265,
#         0.36142551, -0.20903233])

# %%
shapiro(reg_multi.resid)
# Out:
# ShapiroResult(statistic=0.9857882857322693, pvalue=8.540482210328548e-11)

# %% [markdown]
# Ici, l'hypothèse de normalité est remise en cause (p-value =~ 0 < 0.05).<br> Cela étant nous avons un échantillon qui a une grande quantité d'individus (très supérieur à 30), et on observe que graphiquement, même si cela n'est pas parfait, on obtient une distribution qui se rapproche d'une distribution normale.

# %% [markdown]
# ## Test de l'homo-scédasticité

# %% [markdown]
# On peut également tester l’homoscédasticité (c'est-à-dire la constance de la variance) des résidus (des erreurs) :

# %% [markdown]
# (Étymologie de « scédastique » : du grec ancien σκεδαστικός, skedastikos (« dispersif, dissipatif »)

# %% [markdown]
# ![Variance_residus.jpg](attachment:Variance_residus.jpg)

# %% [markdown]
# Hypothèse 𝐻0 : il y a homoscédasticité<br>
# Hypothèse 𝐻A : il y a hétéroscédasticité

# %%
_, pval, __, f_pval = smd.het_breuschpagan(reg_multi.resid, reg_multi.model.exog)
print('p value test Breusch Pagan:', pval)
# Out:
# p value test Breusch Pagan: 7.7595352162174e-16

# %% [markdown]
# La p-valeur ici est quasiment égale à 0, donc très inférieure à 5% : on doit rejetter l'hypothèse 𝐻0 selon laquelle les variances sont constantes (l'hypothèse d’homoscédasticité).
# Potentiellement, notre modèle sera peu fiable.

# %% [markdown]
# ## Variance Inflation Factor (Multicolinéarité)

# %% [markdown]
# VIF = l'équivalent de 1 / (1-R²)
# Plus notre score VIF est élevé pour une variable donnée, plus cette variable est corrélée à d'autre. Elle sera donc redondante, et peut interférer avec notre modèle.

# %%
features = bil.columns.drop(["is_genuine",'margin_low'])
data = reg_multi.model.exog
df = pd.DataFrame(data)

vif = pd.DataFrame()
vif['var'] = features
vif['VIF'] = [variance_inflation_factor(data, i) for i in range(1,data.shape[1])]
display(vif)
# Out:
#             var       VIF
# 0      diagonal  1.013613
# 1   height_left  1.138261
# 2  height_right  1.230115
# 3     margin_up  1.404404
# 4        length  1.576950

# %% [markdown]
# Les scores VIF obtenus sont très inférieurs à 10, on peut donc déduire qu'ici il n'y a pas de problème majeur de colinéarité.

# %% [markdown]
# ## DataFrame complété des données prédites

# %% [markdown]
# **On reconnaît que le modèle n'est pas de très haute fiabilité, néanmoins les données générées peuvent compléter notre dataset initial.**
#
# Nous allons généré un nouveau dataset **bil2**, correspondant au dataset initial complété des données manquantes

# %%
bil2 = bil.copy() # création d'une copie de notre dataframe initial
mask = bil2['margin_low'].isna() # création d'un masque
x_pred = bil2.loc[mask,var_connues]
y_pred = lr.predict(x_pred)
bil2.loc[mask,'margin_low'] = y_pred

# %% [markdown]
# Et voici maintenant le résultat :

# %%
bil2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1500 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
# données incomplètes avec le Dataframe "bil":
bil[bil.isnull().any(axis=1)].head()
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72         True    171.94       103.89        103.45         NaN       3.25
# 99         True    171.93       104.07        104.18         NaN       3.14
# 151        True    172.07       103.80        104.38         NaN       3.02
# 197        True    171.45       103.66        103.80         NaN       3.62
# 241        True    171.83       104.14        104.06         NaN       3.02
#
#      length
# 72   112.79
# 99   113.08
# 151  112.93
# 197  113.27
# 241  112.36

# %%
# données complétées, dans un dataframe "bil2":
bil2.filter(items=[72,99,151,197,241], axis=0)
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72         True    171.94       103.89        103.45    4.318525       3.25
# 99         True    171.93       104.07        104.18    4.393668       3.14
# 151        True    172.07       103.80        104.38    4.410457       3.02
# 197        True    171.45       103.66        103.80    4.319014       3.62
# 241        True    171.83       104.14        104.06    4.650617       3.02
#
#      length
# 72   112.79
# 99   113.08
# 151  112.93
# 197  113.27
# 241  112.36

# %% [markdown]
# # <font color="#8333ff">K-Means</font>
# ou algorithme de classification non-supervisée

# %%
# création d'un Dataframe sans l'information vrai/faux billet
bil_km = bil2.drop("is_genuine",axis=1)
bil_km.head()
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length
# 0    171.81       104.86        104.95        4.52       2.89  112.83
# 1    171.46       103.36        103.66        3.77       2.99  113.09
# 2    172.69       104.48        103.50        4.40       2.94  113.16
# 3    171.36       103.91        103.94        3.62       3.01  113.51
# 4    171.73       104.28        103.46        4.04       3.48  112.54

# %% [markdown]
# ## Détermination du nombre de clusters

# %%
kmeans_kwargs = {"init":"random","n_init":10,"max_iter":300,"random_state":42} # création des arguments de la fonction

# somme des erreurs au carré en fonction du nombre de clusters
sse = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(bil_km)
    sse.append(kmeans.inertia_)
    
sse # visualisation des résultats
# Out:
# [2307.505186419591,
#  972.1153638502299,
#  861.4198134029111,
#  774.7857143616742,
#  711.7269645171599,
#  667.0583959789813,
#  631.9404518508331,
#  596.8840568225004,
#  572.8236023903629]

# %%
plt.style.use("seaborn")
plt.plot(range(1, 10), sse)

plt.title("Graphique du coude")

plt.xlabel("Nombre de clusters")
plt.xticks(range(1,10))

plt.ylabel("SSE (Somme des carrées des erreurs)")
plt.yticks(sse)

plt.show()

# %%
# visuellement on pourrait hésiter entre 2 ou 3 clusters
# la méthode KneeLocator nous indique que le nombre optimal de cluster est de 2 :

kl = KneeLocator(range(1, 10), sse, curve="convex", direction="decreasing")
kl.elbow
# Out:
# 2

# %% [markdown]
# ## Création du modèle

# %%
# création d'une variable kmeans2 pour 2 clusters à partir de notre modèle KMeans
kmeans2 = KMeans(init='random', n_clusters=2, n_init=10, max_iter =300,random_state=42)

# on entraîne notre variable kmeans2 avec les données bil_km_cr
kmeans2.fit(bil_km)
# Out:
# KMeans(init='random', n_clusters=2, random_state=42)

# %%
# on récupère les numéros des labels dans notre variable cl_kmeans
cl_kmeans = kmeans2.labels_

# on crée un dataframe bil_km, rattachant chaque individu de bil2 à son numéro de cluster
bil_clusters = bil2.assign(cl_kmeans=kmeans2.labels_)

# ce qui donne
display(bil_clusters)
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length  cl_kmeans
# ...

# %%
Y_PRED = ~kmeans2.predict(bil_km).astype(bool)

# %%
display(Y_PRED)
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
Y_REAL = bil2["is_genuine"]

# %%
cm_km = confusion_matrix(Y_REAL, Y_PRED)
confusion_matrix_kmeans_display = ConfusionMatrixDisplay(confusion_matrix = cm_km, display_labels = [False, True])
confusion_matrix_kmeans_display.plot()
plt.show()

# %% [markdown]
# ## Prédiction sur les données test

# %%
# import du fichier à tester :
feature_test = pd.read_csv("billets_production_test.csv")
feature_test2 = feature_test.iloc[:,0:-1]

# %%
~kmeans2.predict(feature_test2).astype(bool)
# Out:
# array([False, False, False,  True,  True])

# %% [markdown]
# # <font color="#8333ff">Régression logistique</font>
# (Ou algorithme de classification supervisée)

# %% [markdown]
# On procède ci-dessous à la création de 2 Dataframes :<br> <br>**X** comprenant les varaibles connues (l'ensemble des variables quantitatives) <br>**Y** comprenant la variable à prédire ("is_genuine")

# %%
X = bil2[var_qti]
Y = bil2[['is_genuine']]

# %% [markdown]
# ## Partage des données

# %%
# partage des données en données d'entraînement et données "test"
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,random_state = 0)

# %% [markdown]
# ## Création du modèle

# %%
# Construction du modèle
logr = LogisticRegression()
logr.fit(X_train,Y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# ## Evaluation de la fiabilité des résultats

# %%
# on utilise le modèle pour voir ce qu'il prédit à partir de X_test
# on appelera cette prédiction Y_pred
Y_pred = logr.predict(X_test)
# on connaît la réalité (Y_test)
# on va donc s'en servir comme étalon auquel comparer Y_pred
# plus Y_pred ressemblera à Y_test, plus notre modèle sera correct

# on va utiliser deux méthodes de comparaison:
# la méthode .score
# une matrice de confusion

# %%
display(Y_test.values[0:10]) # les données réelles
display(Y_pred[0:10]) # les données prédites
# Out:
# array([[ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False]])
# array([ True,  True, False,  True, False, False,  True,  True,  True,
#        False])

# %%
cm_log =  confusion_matrix(np.array(Y_test),Y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm_log,display_labels = [False, True])
cm_display.plot()
plt.show()

# %% [markdown]
# ## Prédiction sur les données test

# %%
# prédiction avec les données évaluateur "feature_test2"
logr.predict(feature_test2)
# Out:
# array([False, False, False,  True,  True])

# %% [markdown]
# # <font color="#8333ff">Comparaison des deux modèles<font>

# %% [markdown]
# ## K-Means

# %%
# matrice de confusion

print("Voici notre matrice de confusion pour la méthode K-Means : \n\n"+str(cm_km))

fp_km = cm_km[0,1]
fn_km = cm_km[1,0]

total_km = cm_km[0,0] + cm_km[0,1] + cm_km[1,0] + cm_km[1,1]
precision_kmeans = (100 - round((((fp_km+fn_km)/total_km)*100),2))
# méthode score
print("\nLa précision du modèle est de : "+str(precision_kmeans)+" %")
print("\nSur un échantillon de "+str(total_km)+" occurences :")
print("\nIl y a eu "+str(fp_km)+" faux positif(s)")
print("\nIl y a eu "+str(fn_km)+" faux négatif(s)")
# Out:
# Voici notre matrice de confusion pour la méthode K-Means :
#
# [[481  19]
#  [  3 997]]
#
# La précision du modèle est de : 98.53 %
#
# Sur un échantillon de 1500 occurences :
#
# Il y a eu 19 faux positif(s)
#
# Il y a eu 3 faux négatif(s)

# %% [markdown]
# ## Régression logistique

# %%
# matrice de confusion

print("Voici notre matrice de confusion pour la régression logistique : \n\n"+str(cm_log))

fp_log = cm_log[0,1]
fn_log = cm_log[1,0]

total_log = cm_log[0,0] + cm_log[0,1] + cm_log[1,0] + cm_log[1,1]
# méthode score
print("\nLa précision du modèle est de : "+str((logr.score(X_test,Y_test)*100))+" %")
print("\nSur un échantillon de "+str(total_log)+" occurences :")
print("\nIl y a eu "+str(fp_log)+" faux positif(s)")
print("\nIl y a eu "+str(fn_log)+" faux négatif(s)")
# Out:
# Voici notre matrice de confusion pour la régression logistique :
#
# [[125   1]
#  [  2 247]]
#
# La précision du modèle est de : 99.2 %
#
# Sur un échantillon de 375 occurences :
#
# Il y a eu 1 faux positif(s)
#
# Il y a eu 2 faux négatif(s)

# %% [markdown]
# ## Test sur les nouvelles données

# %%
fichier = pd.read_csv("billets_test1.csv")
test_final = fichier.iloc[:,0:-1]
logr.predict(test_final)
# Out:
# array([ True, False,  True, False, False])

# %%
#~kmeans2.predict(test_final).astype(bool)
